# %% [markdown]
# ##### Imports & load dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_iris
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib
# Will open graphs in a new window. Only useful to move in 3D space with Jupyter Notebook

# Load data
iris = load_iris()
x = iris.data
y = iris.target
names = list(iris.target_names)

# %% [markdown]
# ##### imshow

# %%
plt.imshow(np.corrcoef(x.T), cmap="Blues") # correlation between variables
plt.colorbar()

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)
axe_x = np.linspace(0, 5, 100)
axe_y = np.linspace(0, 5, 100)
x, y = np.meshgrid(axe_x, axe_y)
z = f(x, y)

plt.imshow(z)
